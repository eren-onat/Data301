# %%
import matplotlib as pyplot
import pandas as pd

# %%
df=pd.read_csv('../data301-proj1/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv')

# %%
df= df.drop('Currency - other', axis=1)
df= df.drop('Additional context on job title', axis=1)
df= df.drop('Additional context on income', axis=1)

# %%
df
# Out:
#                 Timestamp How old are you?                       Industry  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 27604   1/8/2022 14:37:49            25-34                         Retail
# 27605   1/8/2022 18:13:03            25-34              Computing or Tech
# 27606   1/9/2022 12:04:28            25-34         Transport or Logistics
# 27607   1/9/2022 22:49:35            25-34              Computing or Tech
# 27608  1/11/2022 13:26:41            55-64   Education (Higher Education)
#
#                                       Job title Annual salary  \
# ...

# %%
df = df.drop(26562)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27608 entries, 0 to 27608
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Timestamp                                 27608 non-null  object
#  1   How old are you?                          27608 non-null  object
#  2   Industry                                  27539 non-null  object
#  3   Job title                                 27608 non-null  object
#  4   Annual salary                             27608 non-null  object
#  5   Other monetary comp                       20462 non-null  float64
#  6   Currency                                  27608 non-null  object
#  7   Country                                   27608 non-null  object
#  8   State                                     22697 non-null  object
#  9   City                                      27530 non-null  object
# ...

# %%
df.isna().any() #pushes out any Nan's in a column
# Out:
# Timestamp                                   False
# How old are you?                            False
# Industry                                     True
# Job title                                   False
# Annual salary                               False
# Other monetary comp                          True
# Currency                                    False
# Country                                     False
# State                                        True
# City                                         True
# Overall years of professional experience    False
# Years of experience in field                False
# Highest level of education completed         True
# Gender                                       True
# Race                                         True
# dtype: bool

# %%
df.drop

# %%
df
# Out:
#                 Timestamp How old are you?                       Industry  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 27604   1/8/2022 14:37:49            25-34                         Retail
# 27605   1/8/2022 18:13:03            25-34              Computing or Tech
# 27606   1/9/2022 12:04:28            25-34         Transport or Logistics
# 27607   1/9/2022 22:49:35            25-34              Computing or Tech
# 27608  1/11/2022 13:26:41            55-64   Education (Higher Education)
#
#                                       Job title  \
# ...
