# %%
# %%writefile utils.py

import utils
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\ereno\\Math 440\\utils.py'>

# %%
utils.my_function()
# Out:
# Hello from utils.py!

# %%
utils.say_hello('Eren')
# Out:
# 'Hello, Eren!'

# %%
utils.hello_world()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 utils.hello_world()
#
# AttributeError: module 'utils' has no attribute 'hello_world'
